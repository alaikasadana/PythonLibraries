# %%
import numpy as np

# %%
data = np.array([
    [10,20,30,40],
    [20,30,40,20]
    ])
print(data[0]+data[1])
# Out:
# [30 50 70 60]

# %%
data = np.array([
    [10,20,30,40],
    [20,30,40,20]
    ])
print(data[0]*data[1])
# Out:
# [ 200  600 1200  800]

# %%
data = np.array([
    [10,20,30,40],
    [20,30,40,20]
    ])
print(data[0]-data[1])
# Out:
# [-10 -10 -10  20]

# %%
data = np.array([
    [10,20,30,40],
    [20,30,40,20]
    ])
print(20+data)
# Out:
# [[30 40 50 60]
#  [40 50 60 40]]

# %%
data = np.array([
    [10,20,30,40],
    [20,30,40,20]
    ])
print(np.square(data))
# Out:
# [[ 100  400  900 1600]
#  [ 400  900 1600  400]]

# %%
print(np.sqrt(data))
# Out:
# [[3.16227766 4.47213595 5.47722558 6.32455532]
#  [4.47213595 5.47722558 6.32455532 4.47213595]]

# %%
exponent = np.exp(data)
print(exponent)
# Out:
# [[2.20264658e+04 4.85165195e+08 1.06864746e+13 2.35385267e+17]
#  [4.85165195e+08 1.06864746e+13 2.35385267e+17 4.85165195e+08]]

# %%
data = np.array([
    [10,20,30,40],
    [20,30,40,20]
    ])
print(np.square(data))
# Out:
# [[ 100  400  900 1600]
#  [ 400  900 1600  400]]

# %%
data = np.array([10,20,30,40,50])
print(data*30)
# Out:
# [ 300  600  900 1200 1500]

# %%
data = np.array([10,20,30,40,50])
print(data+100)
# Out:
# [110 120 130 140 150]

# %%
data = np.array([10,20,30,40,50])
print(np.sum(data))
# Out:
# 150

# %%
a = np.arange(1,5).reshape(2,2)
b = np.arange(6,10).reshape(2,2)
print( a @ b)
# Out:
# [[22 25]
#  [50 57]]

# %%
a = np.arange(1,7).reshape(2,3)
b =np.arange(1,10).reshape(3,3)
# print("b",b)
print( a @ b)
# Out:
# [[30 36 42]
#  [66 81 96]]
