# %% [markdown]
# Calculations on Array

# %%
import numpy as np 

arr = np.array([12,45,80,23,21,2,14,18,29,10])

# %%
arr+2
# Out:
# array([14, 47, 82, 25, 23,  4, 16, 20, 31, 12])

# %%
arr*5
# Out:
# array([ 60, 225, 400, 115, 105,  10,  70,  90, 145,  50])
