# %%
import numpy as np

# Zero dimension 

n = np.array(25)

print("Dimensions : " , n.ndim)
# Out:
# Dimensions :  0

# %%
data = np.array([1,2,3,4,5])

print(np.mean(data))
# Out:
# 3.0

# %%
import pandas as pd

data = {
    "Name": ["sneha", "tiwari"],
    "Age": [18, 19]
}


df = pd.DataFrame(data)
print(df)
# Out:
#      Name  Age
# 0   sneha   18
# 1  tiwari   19

# %%
import numpy as np
import matplotlib.pyplot as mb
data = np.arange(1,10,2)
data1 = np.arange(11,16,1)

mb.plot(data,data1)

# %%
import numpy as np
data = np.array([10,20,30,40,50,60,70])
data = data*10
print(data)
# Out:
# [100 200 300 400 500 600 700]

# %%
import numpy as np

a = np.array([10, 20, 30, 40, 50, 60])
r = []

for i in range(len(a)):
    b = int(a[i] * 2)
    r.append(b)

print(r)
# Out:
# [20, 40, 60, 80, 100, 120]

# %%
a  = np.array([[10,20,30,40,50],
              [90,80,70,60,50]])

b  = np.array([[[[10,20,30,40,50],
              [90,80,70,60,50],
              [90,80,70,60,50],
              [90,80,70,60,50],
              [90,80,70,60,50]]]])

print(a.ndim , b.ndim)
print(a.shape , b.shape)
print(a @ b)
# Out:
# 2 4
# (2, 5) (1, 1, 5, 5)
# [[[[12700 11400 10100  8800  7500]
#    [24300 22600 20900 19200 17500]]]]
