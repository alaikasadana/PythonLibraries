# %%
import numpy as np

# %%
arr = np.full((2,3), 7)

# %%
arr
# Out:
# array([[7, 7, 7],
#        [7, 7, 7]])

# %%
arr = np.full((2,3), [1,2,3])

# %%
arr
# Out:
# array([[1, 2, 3],
#        [1, 2, 3]])

# %%
arr = np.random.rand(5,3)

# %%
arr
# Out:
# array([[0.76557155, 0.3038033 , 0.44197666],
#        [0.61418935, 0.42211326, 0.62201062],
#        [0.88621786, 0.8242337 , 0.96986694],
#        [0.80423225, 0.80497852, 0.75920063],
#        [0.76186463, 0.10323157, 0.85904897]])

# %%
a = [1,2,3,4,5]

arr= np.random.choice(a, (10,10), replace=True, p=[0.3,0.2,0.05,0.05,0.4])

# %%
arr
# Out:
# array([[2, 5, 5, 4, 1, 1, 2, 5, 1, 3],
#        [5, 1, 2, 5, 1, 5, 2, 2, 1, 5],
#        [5, 2, 1, 1, 1, 5, 2, 5, 5, 1],
#        [5, 2, 5, 5, 1, 2, 1, 4, 1, 5],
#        [2, 1, 5, 5, 5, 2, 5, 5, 5, 5],
#        [5, 2, 5, 5, 2, 1, 5, 1, 2, 2],
#        [5, 2, 1, 1, 1, 5, 1, 1, 5, 1],
#        [2, 1, 2, 5, 2, 2, 1, 5, 2, 1],
#        [1, 2, 1, 1, 5, 5, 2, 2, 1, 1],
#        [1, 5, 5, 5, 1, 1, 1, 5, 1, 5]])

# %%
a
# Out:
# [1, 2, 3, 4, 5]

# %%
a = ['T', 'F']

arr= np.random.choice(a, (10,10), replace=True, p=[0.8,0.2])

# %%
arr
# Out:
# array([['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T'],
#        ['T', 'T', 'F', 'T', 'T', 'T', 'T', 'T', 'F', 'F'],
#        ['F', 'F', 'T', 'F', 'T', 'F', 'T', 'T', 'F', 'T'],
#        ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T'],
#        ['F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T'],
#        ['T', 'T', 'T', 'T', 'T', 'F', 'T', 'T', 'T', 'T'],
#        ['T', 'F', 'T', 'F', 'T', 'T', 'T', 'T', 'T', 'T'],
#        ['T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'T'],
#        ['T', 'T', 'F', 'T', 'F', 'T', 'T', 'F', 'T', 'T'],
#        ['T', 'T', 'T', 'F', 'T', 'T', 'T', 'F', 'T', 'F']], dtype='<U1')

# %%
a = ['T', 'F']

arr= np.random.choice(a, (10,10), replace=False, p=[0.8,0.2])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 3
#       1 a = ['T', 'F']
# ----> 3 arr= np.random.choice(a, (10,10), replace=False, p=[0.8,0.2])
#
# File numpy/random/mtrand.pyx:1025, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'

# %%
arr = np.random.randint(0,10,(2,3))

# %%
arr
# Out:
# array([[2, 8, 5],
#        [5, 7, 6]], dtype=int32)

# %%
arr = np.random.randint(0,10,(10,10))

# %%
arr
# Out:
# array([[9, 4, 3, 8, 2, 2, 4, 4, 3, 5],
#        [9, 5, 9, 0, 7, 7, 0, 5, 3, 4],
#        [4, 7, 6, 6, 8, 8, 4, 2, 7, 5],
#        [6, 6, 0, 8, 2, 4, 4, 0, 2, 0],
#        [7, 6, 7, 1, 5, 7, 4, 4, 1, 9],
#        [7, 9, 1, 2, 4, 4, 3, 2, 6, 1],
#        [3, 8, 5, 4, 3, 0, 3, 1, 8, 1],
#        [8, 2, 3, 0, 2, 0, 5, 6, 5, 6],
#        [4, 4, 0, 3, 0, 4, 5, 4, 9, 6],
#        [2, 7, 6, 3, 6, 8, 7, 1, 5, 0]], dtype=int32)

# %%
arr = np.random.randint(5,10,6)
arr
# Out:
# array([9, 9, 5, 5, 8, 9], dtype=int32)

# %%
arr
# Out:
# 4

# %%
a = [1,2,3,4,[5,6,7],8,9]
a
# Out:
# [1, 2, 3, 4, [5, 6, 7], 8, 9]

# %%
a[4][0:3]
# Out:
# [5, 6, 7]

# %%
a
# Out:
# [1, 2, 3, 4, [5, 6, 7], 8, 9]

# %%
print(arr)
# Out:
# [7 5 9 9 8]

# %%
arr[2]
# Out:
# np.int32(9)

# %%
arr = np.array([[1,2,3],[4,5,6]])
print(arr)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
arr[0:1,0:2]
# Out:
# array([[1, 2]])

# %%
arr = np.array([12,13,4,5,45,47,23,31,25,89])
print(arr[arr<20])
# Out:
# [12 13  4  5]

# %%
a = [1,5,9]
arr[a]
# Out:
# array([13, 47, 89])

# %%
print(arr<20)
# Out:
# [ True  True  True  True False False False False False False]

# %%
a = np.array([1,2,3])
b = np.array([4,5,6])

# %%
c =  a + b
c
# Out:
# array([5, 7, 9])

# %%
c =  a - b
c
# Out:
# array([-3, -3, -3])

# %%
a
# Out:
# array([1, 2, 3])

# %%
b
# Out:
# array([4, 5, 6])

# %%
c =  a * b
c
# Out:
# array([ 4, 10, 18])

# %%
c =  a / b
c
# Out:
# array([0.25, 0.4 , 0.5 ])

# %%
c =  a % b
c
# Out:
# array([1, 2, 3])

# %%
c =  a ** b
c
# Out:
# array([  1,  32, 729])
