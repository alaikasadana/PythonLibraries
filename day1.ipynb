# %%
import numpy as np
data = np.array([10,20,30,40])
print(np.mean(data))
# Out:
# 25.0

# %%
import numpy as np
data = np.array([10,20,30,40])
print(np.mean(data))
# Out:
# 25.0

# %%
import numpy as np
data = np.array([10,20,30,40])
print(np.median(data))
# Out:
# 25.0

# %%
import numpy as np
from statistics import mode


data = np.array([10,20,20,30,30,30,40])
print(mode(data))
# Out:
# 30

# %%
import numpy as np

data = np.array([
    [10,20,30,40],
    [50,60,70,80]
])

print(data.ndim)
print(np.sum(data ,axis=0) )
# Out:
# 2
# [ 60  80 100 120]

# %%
import numpy as np

data = np.array([[
    [10,20,30,40,50,60],
    [40,80,90,70,50,10],
    [30,40,60,80,98,90]
]])

print(data.ndim)
print(np.sum(data , axis=1))
# Out:
# 3
# [[ 80 140 180 190 198 160]]
