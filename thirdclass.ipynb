# %%
import numpy as np

# %%
data = np.array([[1,2,3],[4,5,6]])
data.flatten()
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
data.flatten(order='c')
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
data.flatten(order='f')
# Out:
# array([1, 4, 2, 5, 3, 6])

# %%
data.flatten(order='k')
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
data.ravel()
# Out:
# array([1, 2, 3, 4, 5, 6])
