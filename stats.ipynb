# %%
import numpy as np

# %%
arr = np.array([1,5,3,9,7])

# %%
np.mean(arr)
# Out:
# np.float64(5.0)

# %%
np.median(arr)
# Out:
# np.float64(5.0)

# %%
np.min(arr)
# Out:
# np.int64(1)

# %%
np.max(arr)
# Out:
# np.int64(9)

# %%
np.var(arr)
# Out:
# np.float64(8.0)

# %%
np.std(arr)
# Out:
# np.float64(2.8284271247461903)
