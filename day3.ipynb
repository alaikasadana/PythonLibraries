# %%
import matplotlib.pyplot as mp

data = [1,2,4,7,8]
second = [10,30,50,70,90]

mp.plot(data,second)

# %%
import matplotlib.pyplot as mp
import numpy as np 
a = np.arange(1,10)
b = np.arange(11,20)

mp.plot(a,b)

# %%
import numpy as np 
print(np.random.rand(1,50))
# Out:
# [[0.39307646 0.0693085  0.40431769 0.84066503 0.21821427 0.87351611
#   0.68910641 0.63881839 0.51240693 0.67382212 0.05950764 0.76733676
#   0.9227127  0.7956747  0.26761814 0.95058077 0.36526728 0.77670938
#   0.91700148 0.96772705 0.63194588 0.63078897 0.33398287 0.72481798
#   0.43507955 0.56242461 0.00798606 0.87865925 0.69687931 0.52484504
#   0.53500205 0.08827201 0.93243928 0.3729858  0.98237041 0.54585852
#   0.01128989 0.71905904 0.72420016 0.69228703 0.84773765 0.30820746
#   0.25425461 0.54682511 0.1306205  0.09426382 0.14492398 0.62617584
#   0.50978552 0.08698323]]

# %%
import matplotlib.pyplot as mp
import numpy as np 
a = np.arange(1,10,2)
b = np.arange(11,20,2)

mp.plot(a,b)

# %%
import numpy as np 
print(np.random.rand(1,50).shape)
# Out:
# (1, 50)
