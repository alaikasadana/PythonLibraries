# %% [markdown]
# Input  & Output Functions

# %%
import numpy as np

# %%
arr = np.array([1,5,3,9,7])

# %%
np.save("save.npy",arr)

# %%
np.load("save.npy")
# Out:
# array([1, 5, 3, 9, 7])

# %%
np.savetxt("text.txt",arr)

# %%
np.loadtxt("text.txt")
# Out:
# array([1., 5., 3., 9., 7.])
