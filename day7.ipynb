# %%
import numpy as np

# %%
data=np.array([1,2,3,4,5,6,7,8])
print(np.mean(data))
# Out:
# 4.5

# %%
a = np.array([1,2,3,4])
print(np.median(a))
# Out:
# 2.5

# %%
data = np.array(np.deg2rad([3,6,8,100,-23]))
print(np.std(data))
# Out:
# 0.7351462721722711

# %%
data = np.array([3,6,8,100,-23])
print(np.var(data))
# Out:
# 1774.1599999999999
