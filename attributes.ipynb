# %% [markdown]
# Attributes of Array

# %%
import numpy as np

# %%
import numpy as np

data = np.array([
    [[1, 2], [3, 4]],
    [[5, 6], [7, 8]]
])

print(data)
data
# Out:
# [[[1 2]
#   [3 4]]
#
#  [[5 6]
#   [7 8]]]
# array([[[1, 2],
#         [3, 4]],
#
#        [[5, 6],
#         [7, 8]]])

# %%
print(np.shape(data))
# Out:
# (2, 2, 2)

# %%
print(np.ndim(data))
# Out:
# 3

# %%
print(np.size(data))
# Out:
# 8

# %%
print(data.dtype)
# Out:
# int64
