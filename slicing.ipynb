# %% [markdown]
# Slicing

# %% [markdown]
# Slicing With List

# %%
a = [1,2,3,4,[5,6,7],8,9]
print(a[0:4])

print(a[4][1])
# Out:
# [1, 2, 3, 4]
# 6

# %% [markdown]
# Slicing With Array

# %%
import numpy as np

# %%
arr = np.array([1,2,4,5,6,7,7,8,8])
arr[2]
# Out:
# np.int64(4)
